# %%
import pandas as pd
import numpy as np

#create a pandas dataframe
df= pd.DataFrame({
    'Id': [1,2,3,4,5] ,
    'Name': ['John', 'Steve', 'Sarah', 'Jane', 'David'],
    'Age': [23, 34, 45, 56, 67]
})

# %%
df
# Out:
#    Id   Name  Age
# 0   1   John   23
# 1   2  Steve   34
# 2   3  Sarah   45
# 3   4   Jane   56
# 4   5  David   67

# %%
df.to_csv('mydata.csv', index=False)

# %%
#load the dataset
df=pd.read_csv('car_price_prediction.csv')

# %%
#get the top 5 rows
df.head()
# Out:
#            ID    Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403.0  13328.0  1399        LEXUS   RX 450      2010.0       Jeep
# 1  44731507.0  16621.0  1018    CHEVROLET  Equinox      2011.0       Jeep
# 2  45774419.0   8467.0     -        HONDA      FIT      2006.0  Hatchback
# 3  45769185.0   3607.0   862         FORD   Escape      2011.0       Jeep
# 4  45809263.0  11726.0   446        HONDA      FIT      2014.0  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# ...

# %%
#get the last 5 rows

df.tail()
# Out:
#                ID    Price  Levy   Manufacturer    Model  Prod. year Category  \
# 19232  45798355.0   8467.0     -  MERCEDES-BENZ  CLK 200      1999.0    Coupe
# 19233  45778856.0  15681.0   831        HYUNDAI   Sonata      2011.0    Sedan
# 19234  45804997.0  26108.0   836        HYUNDAI   Tucson      2010.0     Jeep
# 19235  45793526.0   5331.0  1288      CHEVROLET  Captiva      2007.0     Jeep
# 19236  45813273.0    470.0   753        HYUNDAI   Sonata      2012.0    Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors       Wheel   Color  Airbags
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923600e+04  1.923500e+04  19236.000000  19237.000000  19237.000000
# mean   4.557653e+07  1.855635e+04   2010.913444      4.582991      6.582627
# std    9.366149e+05  1.905911e+05      5.668170      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577232e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.206900e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19236 non-null  float64
#  1   Price             19235 non-null  float64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19236 non-null  object
#  5   Prod. year        19236 non-null  float64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19236 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
df.head(10)
# Out:
#            ID    Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403.0  13328.0  1399        LEXUS    RX 450      2010.0       Jeep
# 1  44731507.0  16621.0  1018    CHEVROLET   Equinox      2011.0       Jeep
# 2  45774419.0   8467.0     -        HONDA       FIT      2006.0  Hatchback
# 3  45769185.0   3607.0   862         FORD    Escape      2011.0       Jeep
# 4  45809263.0  11726.0   446        HONDA       FIT      2014.0  Hatchback
# 5  45802912.0  39493.0   891      HYUNDAI  Santa FE      2016.0       Jeep
# 6  45656768.0   1803.0   761       TOYOTA     Prius      2010.0  Hatchback
# 7  45816158.0    549.0   751      HYUNDAI    Sonata      2013.0      Sedan
# 8  45641395.0   1098.0   394       TOYOTA       NaN      2014.0      Sedan
# 9  45756839.0  26657.0     -        LEXUS    RX 350      2007.0       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# ...

# %%
#get the 10th to the 20th rows

df2=df[10:21]

df2
# Out:
#             ID    Price  Levy   Manufacturer     Model  Prod. year  \
# 10  45621750.0    941.0  1053  MERCEDES-BENZ     E 350      2014.0
# 11  45814819.0   8781.0     -           FORD   Transit         NaN
# 12  45815568.0   3000.0     -           OPEL    Vectra      1997.0
# 13  45661288.0   1019.0  1055          LEXUS    RX 450      2013.0
# 14  45732604.0  59464.0   891        HYUNDAI  Santa FE      2016.0
# 15  45465200.0      NaN  1079         TOYOTA       CHR      2018.0
# 16  45772281.0   7683.0   810        HYUNDAI   Elantra      2016.0
# 17  45797221.0      NaN   810        HYUNDAI   Elantra      2016.0
# 18  45772104.0    549.0  2386        HYUNDAI    Sonata      2006.0
# 19  45653306.0    941.0  1850          LEXUS    RX 400      2008.0
# 20  45801686.0  18826.0   531        HYUNDAI   Elantra      2012.0
#
#        Category Leather interior Fuel type Engine volume    Mileage  \
# 10        Sedan              Yes    Diesel           3.5  184467 km
# ...

# %%
#select the columns ID, Price, Levy, Manufacturer and add them to a new datagrame

mydf=df[['ID', 'Price', 'Levy', 'Manufacturer']]

mydf
# Out:
#                ID    Price  Levy   Manufacturer
# 0      45654403.0  13328.0  1399          LEXUS
# 1      44731507.0  16621.0  1018      CHEVROLET
# 2      45774419.0   8467.0     -          HONDA
# 3      45769185.0   3607.0   862           FORD
# 4      45809263.0  11726.0   446          HONDA
# ...           ...      ...   ...            ...
# 19232  45798355.0   8467.0     -  MERCEDES-BENZ
# 19233  45778856.0  15681.0   831        HYUNDAI
# 19234  45804997.0  26108.0   836        HYUNDAI
# 19235  45793526.0   5331.0  1288      CHEVROLET
# 19236  45813273.0    470.0   753        HYUNDAI
#
# [19237 rows x 4 columns]

# %%
#rename column
result= mydf.rename(columns={'Levy':'Incentive', 'ID':'NIC'})

result
# Out:
#               NIC    Price Incentive   Manufacturer
# 0      45654403.0  13328.0      1399          LEXUS
# 1      44731507.0  16621.0      1018      CHEVROLET
# 2      45774419.0   8467.0         -          HONDA
# 3      45769185.0   3607.0       862           FORD
# 4      45809263.0  11726.0       446          HONDA
# ...           ...      ...       ...            ...
# 19232  45798355.0   8467.0         -  MERCEDES-BENZ
# 19233  45778856.0  15681.0       831        HYUNDAI
# 19234  45804997.0  26108.0       836        HYUNDAI
# 19235  45793526.0   5331.0      1288      CHEVROLET
# 19236  45813273.0    470.0       753        HYUNDAI
#
# [19237 rows x 4 columns]

# %%
mydf
# Out:
#                ID    Price  Levy   Manufacturer
# 0      45654403.0  13328.0  1399          LEXUS
# 1      44731507.0  16621.0  1018      CHEVROLET
# 2      45774419.0   8467.0     -          HONDA
# 3      45769185.0   3607.0   862           FORD
# 4      45809263.0  11726.0   446          HONDA
# ...           ...      ...   ...            ...
# 19232  45798355.0   8467.0     -  MERCEDES-BENZ
# 19233  45778856.0  15681.0   831        HYUNDAI
# 19234  45804997.0  26108.0   836        HYUNDAI
# 19235  45793526.0   5331.0  1288      CHEVROLET
# 19236  45813273.0    470.0   753        HYUNDAI
#
# [19237 rows x 4 columns]

# %%
#inplace=True will modify the original dataframe
mydf.rename(columns={'Levy':'Incentive', 'ID':'NIC'},inplace=True)

mydf
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/3647134190.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf.rename(columns={'Levy':'Incentive', 'ID':'NIC'},inplace=True)
#               NIC    Price Incentive   Manufacturer
# 0      45654403.0  13328.0      1399          LEXUS
# 1      44731507.0  16621.0      1018      CHEVROLET
# 2      45774419.0   8467.0         -          HONDA
# 3      45769185.0   3607.0       862           FORD
# 4      45809263.0  11726.0       446          HONDA
# ...           ...      ...       ...            ...
# 19232  45798355.0   8467.0         -  MERCEDES-BENZ
# 19233  45778856.0  15681.0       831        HYUNDAI
# 19234  45804997.0  26108.0       836        HYUNDAI
# 19235  45793526.0   5331.0      1288      CHEVROLET
# ...

# %%
#add column profit =0 to the dataframe

mydf['Profit']=0

mydf
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/2740532849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf['Profit']=0
#               NIC    Price Incentive   Manufacturer  Profit
# 0      45654403.0  13328.0      1399          LEXUS       0
# 1      44731507.0  16621.0      1018      CHEVROLET       0
# 2      45774419.0   8467.0         -          HONDA       0
# 3      45769185.0   3607.0       862           FORD       0
# 4      45809263.0  11726.0       446          HONDA       0
# ...           ...      ...       ...            ...     ...
# 19232  45798355.0   8467.0         -  MERCEDES-BENZ       0
# 19233  45778856.0  15681.0       831        HYUNDAI       0
# ...

# %%
#delete the column profit
mydf.drop('Profit', axis=1, inplace=True)
mydf
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/651665197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf.drop('Profit', axis=1, inplace=True)
#               NIC    Price Incentive   Manufacturer
# 0      45654403.0  13328.0      1399          LEXUS
# 1      44731507.0  16621.0      1018      CHEVROLET
# 2      45774419.0   8467.0         -          HONDA
# 3      45769185.0   3607.0       862           FORD
# 4      45809263.0  11726.0       446          HONDA
# ...           ...      ...       ...            ...
# 19232  45798355.0   8467.0         -  MERCEDES-BENZ
# 19233  45778856.0  15681.0       831        HYUNDAI
# 19234  45804997.0  26108.0       836        HYUNDAI
# 19235  45793526.0   5331.0      1288      CHEVROLET
# ...

# %%
mydf.drop(['NIC','Price'], axis=1, inplace=True)
mydf
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/1909751798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf.drop(['NIC','Price'], axis=1, inplace=True)
#       Incentive   Manufacturer
# 0          1399          LEXUS
# 1          1018      CHEVROLET
# 2             -          HONDA
# 3           862           FORD
# 4           446          HONDA
# ...         ...            ...
# 19232         -  MERCEDES-BENZ
# 19233       831        HYUNDAI
# 19234       836        HYUNDAI
# 19235      1288      CHEVROLET
# 19236       753        HYUNDAI
#
# [19237 rows x 2 columns]

# %%
df
# Out:
#                ID    Price  Levy   Manufacturer    Model  Prod. year  \
# 0      45654403.0  13328.0  1399          LEXUS   RX 450      2010.0
# 1      44731507.0  16621.0  1018      CHEVROLET  Equinox      2011.0
# 2      45774419.0   8467.0     -          HONDA      FIT      2006.0
# 3      45769185.0   3607.0   862           FORD   Escape      2011.0
# 4      45809263.0  11726.0   446          HONDA      FIT      2014.0
# ...           ...      ...   ...            ...      ...         ...
# 19232  45798355.0   8467.0     -  MERCEDES-BENZ  CLK 200      1999.0
# 19233  45778856.0  15681.0   831        HYUNDAI   Sonata      2011.0
# 19234  45804997.0  26108.0   836        HYUNDAI   Tucson      2010.0
# 19235  45793526.0   5331.0  1288      CHEVROLET  Captiva      2007.0
# 19236  45813273.0    470.0   753        HYUNDAI   Sonata      2012.0
#
#         Category Leather interior Fuel type Engine volume    Mileage  \
# ...

# %%
df3=df[['ID', 'Price', 'Levy', 'Manufacturer']]

df3
# Out:
#                ID    Price  Levy   Manufacturer
# 0      45654403.0  13328.0  1399          LEXUS
# 1      44731507.0  16621.0  1018      CHEVROLET
# 2      45774419.0   8467.0     -          HONDA
# 3      45769185.0   3607.0   862           FORD
# 4      45809263.0  11726.0   446          HONDA
# ...           ...      ...   ...            ...
# 19232  45798355.0   8467.0     -  MERCEDES-BENZ
# 19233  45778856.0  15681.0   831        HYUNDAI
# 19234  45804997.0  26108.0   836        HYUNDAI
# 19235  45793526.0   5331.0  1288      CHEVROLET
# 19236  45813273.0    470.0   753        HYUNDAI
#
# [19237 rows x 4 columns]

# %%
df3['Price']=df3['Price']*2

df3
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/520552961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Price']=df3['Price']*2
#                ID    Price  Levy   Manufacturer
# 0      45654403.0  26656.0  1399          LEXUS
# 1      44731507.0  33242.0  1018      CHEVROLET
# 2      45774419.0  16934.0     -          HONDA
# 3      45769185.0   7214.0   862           FORD
# 4      45809263.0  23452.0   446          HONDA
# ...           ...      ...   ...            ...
# 19232  45798355.0  16934.0     -  MERCEDES-BENZ
# 19233  45778856.0  31362.0   831        HYUNDAI
# 19234  45804997.0  52216.0   836        HYUNDAI
# 19235  45793526.0  10662.0  1288      CHEVROLET
# ...

# %%
#get mean price of the cars
mean_price=df3['Price'].mean()
mean_price
# Out:
# 37112.70506888485

# %%
#Data cleaning
#check for missing values
df3.isna().sum()
# Out:
# ID              1
# Price           2
# Levy            0
# Manufacturer    0
# dtype: int64

# %%
#eliminate missing values
df3.dropna(inplace=True)


# df3.fillna(0, inplace=True)

df3.isna().sum()
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/3258172479.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.dropna(inplace=True)
# ID              0
# Price           0
# Levy            0
# Manufacturer    0
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19234 entries, 0 to 19236
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            19234 non-null  float64
#  1   Price         19234 non-null  float64
#  2   Levy          19234 non-null  object
#  3   Manufacturer  19234 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 751.3+ KB

# %%
df3['ID']=df3['ID'].astype('int64')
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_22523/217374904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ID']=df3['ID'].astype('int64')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19234 entries, 0 to 19236
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            19234 non-null  int64
#  1   Price         19234 non-null  float64
#  2   Levy          19234 non-null  object
#  3   Manufacturer  19234 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 751.3+ KB

# %%
#get some stats
print(df3['Price'].min())
print(df3['Price'].max())
print(df3['Price'].mean())
print(df3['Price'].std())
print(df3['Price'].median())
# Out:
# 2.0
# 52615000.0
# 37112.808464178015
# 381192.15037478815
# 26344.0

# %%
df.head()
# Out:
#            ID    Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403.0  13328.0  1399        LEXUS   RX 450      2010.0       Jeep
# 1  44731507.0  16621.0  1018    CHEVROLET  Equinox      2011.0       Jeep
# 2  45774419.0   8467.0     -        HONDA      FIT      2006.0  Hatchback
# 3  45769185.0   3607.0   862         FORD   Escape      2011.0       Jeep
# 4  45809263.0  11726.0   446        HONDA      FIT      2014.0  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# ...

# %%
#group by manufacturer
df.groupby('Manufacturer')['ID'].count()
# Out:
# Manufacturer
# ACURA            15
# ALFA ROMEO        4
# ASTON MARTIN      1
# AUDI            255
# BENTLEY           2
#                ...
# VAZ              48
# VOLKSWAGEN      579
# VOLVO            19
# ZAZ               2
# სხვა              2
# Name: ID, Length: 65, dtype: int64

# %%
df.groupby('Manufacturer')['Price'].mean()
# Out:
# Manufacturer
# ACURA             5910.933333
# ALFA ROMEO        9890.250000
# ASTON MARTIN     54000.000000
# AUDI             14106.545098
# BENTLEY         197574.500000
#                     ...
# VAZ               4613.583333
# VOLKSWAGEN       11640.421416
# VOLVO            10278.894737
# ZAZ               3822.500000
# სხვა             17248.500000
# Name: Price, Length: 65, dtype: float64

# %%
df['Manufacturer'].unique()
# Out:
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'OPEL', 'PORSCHE', 'BMW', 'JEEP', 'VOLKSWAGEN',
#        'AUDI', 'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'ACURA', 'LINCOLN', 'VAZ', 'GAZ',
#        'CITROEN', 'LAND ROVER', 'MINI', 'DODGE', 'CHRYSLER', 'JAGUAR',
#        'ISUZU', 'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC',
#        'PEUGEOT', 'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION',
#        'UAZ', 'MERCURY', 'ZAZ', 'ROVER', 'SEAT', 'LANCIA', 'MOSKVICH',
#        'MASERATI', 'FERRARI', 'SAAB', 'LAMBORGHINI', 'ROLLS-ROYCE',
#        'PONTIAC', 'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
#query the dataframe

#get all cars of manufacturer Toyota with less than 50000 miles and hybrid fuel type
df.rename(columns={'Fuel type':'Fuel_type'}, inplace=True)

result=df.query('Manufacturer=="TOYOTA" and Fuel_type=="Hybrid"')
result
# Out:
#                ID    Price  Levy Manufacturer       Model  Prod. year  \
# 6      45656768.0   1803.0   761       TOYOTA       Prius      2010.0
# 8      45641395.0   1098.0   394       TOYOTA         NaN      2014.0
# 27     45804684.0     30.0     -       TOYOTA       Prius      2008.0
# 29     45768550.0  12074.0  1537       TOYOTA  Highlander      2009.0
# 33     45770026.0    125.0  1750       TOYOTA  Highlander      2008.0
# ...           ...      ...   ...          ...         ...         ...
# 19213  45657109.0   6586.0   988       TOYOTA       Prius      2007.0
# 19214  45812999.0   1176.0   986       TOYOTA       Camry      2010.0
# 19219  45789241.0  19444.0     -       TOYOTA       Prius      2013.0
# 19229  39977395.0     50.0     -       TOYOTA       Prius      2008.0
# 19230  45760891.0    470.0   645       TOYOTA       Prius      2011.0
#
#         Category Leather interior Fuel_type Engine volume    Mileage  \
# ...

# %%
#simple query
result=df[df['Manufacturer']=='TOYOTA']
result
# Out:
#                ID    Price  Levy Manufacturer  Model  Prod. year   Category  \
# 6      45656768.0   1803.0   761       TOYOTA  Prius      2010.0  Hatchback
# 8      45641395.0   1098.0   394       TOYOTA    NaN      2014.0      Sedan
# 15     45465200.0      NaN  1079       TOYOTA    CHR      2018.0       Jeep
# 21     45168471.0  20698.0   586       TOYOTA  Prius      2012.0      Sedan
# 22            NaN  17562.0  1249       TOYOTA  Camry      2017.0      Sedan
# ...           ...      ...   ...          ...    ...         ...        ...
# 19214  45812999.0   1176.0   986       TOYOTA  Camry      2010.0      Sedan
# 19216  45784464.0  37633.0  1249       TOYOTA  RAV 4      2017.0       Jeep
# 19219  45789241.0  19444.0     -       TOYOTA  Prius      2013.0      Sedan
# 19229  39977395.0     50.0     -       TOYOTA  Prius      2008.0  Hatchback
# 19230  45760891.0    470.0   645       TOYOTA  Prius      2011.0  Hatchback
#
# ...

# %%
df['Manufacturer']=df['Manufacturer'].str.lower()

df['Manufacturer']
# Out:
# 0                lexus
# 1            chevrolet
# 2                honda
# 3                 ford
# 4                honda
#              ...
# 19232    mercedes-benz
# 19233          hyundai
# 19234          hyundai
# 19235        chevrolet
# 19236          hyundai
# Name: Manufacturer, Length: 19237, dtype: object

# %%
df.sort_values(by='Manufacturer',ascending=True).head(100)
# Out:
#                ID    Price  Levy Manufacturer     Model  Prod. year Category  \
# 13786  45766207.0   4861.0  1234        acura       MDX      2011.0     Jeep
# 14717  45754857.0   4391.0  1053        acura       RDX      2014.0     Jeep
# 3418   45754293.0   2979.0   986        acura       TSX      2010.0    Sedan
# 14679  45815288.0     69.0     -        acura  TL saber      2001.0    Sedan
# 1010   45808694.0   3450.0   900        acura       TLX      2015.0    Sedan
# ...           ...      ...   ...          ...       ...         ...      ...
# 12664  45782093.0  10976.0     -         audi     A4 S4      2008.0    Sedan
# 6892   45808414.0   9095.0  1661         audi        A5      2013.0    Coupe
# 16854  45809830.0    627.0  1481         audi        Q7      2017.0     Jeep
# 13485  45758423.0    862.0   707         audi        A4      2011.0    Sedan
# 10043  45799078.0   6000.0     -         audi        A4      2003.0    Sedan
#
# ...

# %%
df.head()
# Out:
#            ID    Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403.0  13328.0  1399        lexus   RX 450      2010.0       Jeep
# 1  44731507.0  16621.0  1018    chevrolet  Equinox      2011.0       Jeep
# 2  45774419.0   8467.0     -        honda      FIT      2006.0  Hatchback
# 3  45769185.0   3607.0   862         ford   Escape      2011.0       Jeep
# 4  45809263.0  11726.0   446        honda      FIT      2014.0  Hatchback
#
#   Leather interior Fuel_type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19236 non-null  float64
#  1   Price             19235 non-null  float64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19236 non-null  object
#  5   Prod. year        19236 non-null  float64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel_type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19236 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
#visualise box plot for price
#clean price


df5=df[df['Price']<40000]
df5["Price"].plot(kind='box')
# Out:
# <Axes: >

# %%
#pie chart for number of cars of each brand

count=df['Manufacturer'].value_counts()

count.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
values=df5.query('Manufacturer=="bmw" or Manufacturer=="toyota" or Manufacturer=="lexus"')
values=values.groupby('Manufacturer')['Price'].mean()
values.plot(kind='bar')
# values
# Out:
# <Axes: xlabel='Manufacturer'>
