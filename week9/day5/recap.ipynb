# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("beridzeg45/diamonds-prices-prediction")

# print("Path to dataset files:", path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diamonds.csv")

df
# Out:
#                  Shape    Cut Color Clarity  Carat Weight  Length/Width Ratio  \
# 0     Cushion Modified  Ideal     F    VVS2          1.84                1.02
# 1                 Pear    NaN     E     VS1          1.20                1.65
# 2                 Oval    NaN     E     VS1          1.19                1.41
# 3                Heart    NaN     D      IF          1.00                1.18
# 4              Radiant    NaN     H     VS1          1.01                1.35
# ...                ...    ...   ...     ...           ...                 ...
# 6480              Pear    NaN     F     VS2          1.02                1.54
# 6481             Heart    NaN     E    VVS2          1.00                1.16
# 6482          Princess  Ideal     G    VVS1          1.03                1.01
# 6483           Radiant    NaN     E     VS1          1.06                1.43
# 6484           Emerald    NaN     H    VVS1          1.00                1.36
#
# ...

# %%
df.columns
# Out:
# Index(['Shape', 'Cut', 'Color', 'Clarity', 'Carat Weight',
#        'Length/Width Ratio', 'Depth %', 'Table %', 'Polish', 'Symmetry',
#        'Girdle', 'Culet', 'Length', 'Width', 'Height', 'Price', 'Type',
#        'Fluorescence'],
#       dtype='object')

# %%
#cleaning

df.isna().sum()
# Out:
# Shape                    5
# Cut                   4303
# Color                    5
# Clarity                  5
# Carat Weight             5
# Length/Width Ratio       5
# Depth %                  7
# Table %                 17
# Polish                  20
# Symmetry                20
# Girdle                  22
# Culet                 4594
# Length                  20
# Width                   20
# Height                  20
# Price                    0
# Type                     0
# Fluorescence          5264
# dtype: int64

# %%
df['Cut'].unique()
# Out:
# array(['Ideal', nan, 'Very Good', 'Excellent', 'Astor'], dtype=object)

# %%
df['Cut'].fillna('NA',inplace=True)
df['Fluorescence'].fillna('NA',inplace=True)
df['Culet'].fillna('NA',inplace=True)
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_29215/4268423568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cut'].fillna('NA',inplace=True)
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_29215/4268423568.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isna().sum()
# Out:
# Shape                  5
# Cut                    0
# Color                  5
# Clarity                5
# Carat Weight           5
# Length/Width Ratio     5
# Depth %                7
# Table %               17
# Polish                20
# Symmetry              20
# Girdle                22
# Culet                  0
# Length                20
# Width                 20
# Height                20
# Price                  0
# Type                   0
# Fluorescence           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Shape                 0
# Cut                   0
# Color                 0
# Clarity               0
# Carat Weight          0
# Length/Width Ratio    0
# Depth %               0
# Table %               0
# Polish                0
# Symmetry              0
# Girdle                0
# Culet                 0
# Length                0
# Width                 0
# Height                0
# Price                 0
# Type                  0
# Fluorescence          0
# dtype: int64

# %%
df
# Out:
#                  Shape    Cut Color Clarity  Carat Weight  Length/Width Ratio  \
# 0     Cushion Modified  Ideal     F    VVS2          1.84                1.02
# 1                 Pear     NA     E     VS1          1.20                1.65
# 2                 Oval     NA     E     VS1          1.19                1.41
# 3                Heart     NA     D      IF          1.00                1.18
# 4              Radiant     NA     H     VS1          1.01                1.35
# ...                ...    ...   ...     ...           ...                 ...
# 6480              Pear     NA     F     VS2          1.02                1.54
# 6481             Heart     NA     E    VVS2          1.00                1.16
# 6482          Princess  Ideal     G    VVS1          1.03                1.01
# 6483           Radiant     NA     E     VS1          1.06                1.43
# 6484           Emerald     NA     H    VVS1          1.00                1.36
#
# ...

# %%
df.rename(columns={'Carat Weight':'Carat_Weight', 'Length/Width Ratio': 'LWRatio','Depth %':'Depth','Table %':'Table'},inplace=True)

df.head()
# Out:
#               Shape    Cut Color Clarity  Carat_Weight  LWRatio  Depth  Table  \
# 0  Cushion Modified  Ideal     F    VVS2          1.84     1.02   65.8   59.0
# 1              Pear     NA     E     VS1          1.20     1.65   62.5   58.0
# 2              Oval     NA     E     VS1          1.19     1.41   63.1   63.0
# 3             Heart     NA     D      IF          1.00     1.18   61.7   58.0
# 4           Radiant     NA     H     VS1          1.01     1.35   69.4   66.0
#
#       Polish   Symmetry                        Girdle Culet  Length  Width  \
# 0  Excellent  Very Good               Medium to Thick    NA    7.09   6.95
# 1  Very Good  Very Good               Medium to Thick    NA    9.64   5.86
# 2  Very Good  Very Good               Medium to Thick    NA    8.44   6.00
# 3  Excellent  Excellent  Slightly Thick to Very Thick    NA    5.85   6.89
# 4  Excellent  Very Good                         Thick    NA    6.80   5.05
#
#    Height  Price           Type Fluorescence
# ...

# %%
df.describe()
# Out:
#        Carat_Weight      LWRatio        Depth        Table       Length  \
# count   6463.000000  6463.000000  6463.000000  6463.000000  6463.000000
# mean       1.234750     1.329598    64.208278    61.829723     7.663778
# std        0.505706     0.325695     4.774312     4.761072     1.674888
# min        1.000000     1.000000    46.100000    51.000000     5.180000
# 25%        1.010000     1.020000    61.200000    58.000000     6.330000
# 50%        1.030000     1.270000    63.100000    61.000000     7.420000
# 75%        1.190000     1.510000    67.600000    65.000000     8.660000
# max        9.380000     2.580000    77.000000    78.000000    15.210000
#
#              Width       Height         Price
# count  6463.000000  6463.000000   6463.000000
# mean      6.097910     3.885482   3527.302027
# std       1.151036     0.599376   3275.915447
# min       4.420000     2.670000   1010.000000
# 25%       5.390000     3.460000   1210.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6463 entries, 0 to 6484
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Shape         6463 non-null   object
#  1   Cut           6463 non-null   object
#  2   Color         6463 non-null   object
#  3   Clarity       6463 non-null   object
#  4   Carat_Weight  6463 non-null   float64
#  5   LWRatio       6463 non-null   float64
#  6   Depth         6463 non-null   float64
#  7   Table         6463 non-null   float64
#  8   Polish        6463 non-null   object
#  9   Symmetry      6463 non-null   object
#  10  Girdle        6463 non-null   object
#  11  Culet         6463 non-null   object
#  12  Length        6463 non-null   float64
#  13  Width         6463 non-null   float64
#  14  Height        6463 non-null   float64
#  15  Price         6463 non-null   int64
#  16  Type          6463 non-null   object
#  17  Fluorescence  6463 non-null   object
# ...

# %%
#encode all non numeric columns to numeric in df2
df2=df.copy()
from sklearn.preprocessing import LabelEncoder

shape_encoder=LabelEncoder()
shape_encoder.fit(df2['Shape'])

cut_encoder=LabelEncoder()
cut_encoder.fit(df2['Cut'])

color_encoder=LabelEncoder()
color_encoder.fit(df2['Color'])

clarity_encoder=LabelEncoder()
clarity_encoder.fit(df2['Clarity'])

polish_encoder=LabelEncoder()
polish_encoder.fit(df2['Polish'])

symmetry_encoder=LabelEncoder()
symmetry_encoder.fit(df2['Symmetry'])

girdle_encoder=LabelEncoder()
girdle_encoder.fit(df2['Girdle'])

culet_encoder=LabelEncoder()
culet_encoder.fit(df2['Culet'])

type_encoder=LabelEncoder()
type_encoder.fit(df2['Type'])

fluorescence_encoder=LabelEncoder()
fluorescence_encoder.fit(df2['Fluorescence'])

df2['Shape']=shape_encoder.transform(df2['Shape'])
df2['Cut']=cut_encoder.transform(df2['Cut'])
df2['Color']=color_encoder.transform(df2['Color'])
df2['Clarity']=clarity_encoder.transform(df2['Clarity'])
df2['Polish']=polish_encoder.transform(df2['Polish'])
df2['Symmetry']=symmetry_encoder.transform(df2['Symmetry'])
df2['Girdle']=girdle_encoder.transform(df2['Girdle'])
df2['Culet']=culet_encoder.transform(df2['Culet'])
df2['Type']=type_encoder.transform(df2['Type'])
df2['Fluorescence']=fluorescence_encoder.transform(df2['Fluorescence'])

# %%
df2.head()
# Out:
#    Shape  Cut  Color  Clarity  Carat_Weight  LWRatio  Depth  Table  Polish  \
# 0      1    2      2        5          1.84     1.02   65.8   59.0       0
# 1      6    3      1        2          1.20     1.65   62.5   58.0       2
# 2      5    3      1        2          1.19     1.41   63.1   63.0       2
# 3      3    3      0        1          1.00     1.18   61.7   58.0       0
# 4      8    3      4        2          1.01     1.35   69.4   66.0       0
#
#    Symmetry  Girdle  Culet  Length  Width  Height  Price  Type  Fluorescence
# 0         2       7      1    7.09   6.95    4.57   2640     1             2
# 1         2       7      1    9.64   5.86    3.66   1070     1             2
# 2         2       7      1    8.44   6.00    3.79   1070     1             2
# 3         0      13      1    5.85   6.89    4.25   7110     0             0
# 4         2      14      1    6.80   5.05    3.50   3050     0             2

# %%
#correlation matrix
corr = df2.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
x=df2.drop(['Price'],axis=1)
y=df2['Price']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

x_train_original=x_train.copy()
x_test_original=x_test.copy()
y_train_original=y_train.copy()
y_test_original=y_test.copy()

# %%
#linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lr_model=LinearRegression()
lr_model.fit(x_train,y_train)

y_pred=lr_model.predict(x_test)
accuracy=lr_model.score(x_test,y_test)
print("Accuracy of Linear Regression model: ",accuracy)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error of Linear Regression model: ",rmse)
# Out:
# Accuracy of Linear Regression model:  0.5836764994818626
# Root Mean Squared Error of Linear Regression model:  2241.2665929531468

# %%
#box plot for price
plt.figure(figsize=(10,10))
sns.boxplot(y='Price',data=df2)
# Out:
# <Axes: ylabel='Price'>

# %%
df3=df2.query('Price<=8500')
df3.shape
# Out:
# (6215, 18)

# %%
#box plot for price
plt.figure(figsize=(10,10))
sns.boxplot(y='Price',data=df3)
# Out:
# <Axes: ylabel='Price'>

# %%
x=df3.drop(['Price'],axis=1)
y=df3['Price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

lr_model2=LinearRegression()
lr_model2.fit(x_train,y_train)

y_pred=lr_model2.predict(x_test)
accuracy=lr_model2.score(x_test,y_test)
print("Accuracy of Linear Regression model for price<=10000: ",accuracy)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error of Linear Regression model for price<=10000: ",rmse)
# Out:
# Accuracy of Linear Regression model for price<=10000:  0.7342852064117285
# Root Mean Squared Error of Linear Regression model for price<=10000:  884.7552833192145

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

lr_model3=LogisticRegression()
lr_model3.fit(x_train,y_train)
y_pred=lr_model3.predict(x_test)
accuracy=lr_model3.score(x_test,y_test)
print("Accuracy of Logistic Regression model: ",accuracy)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error of Logistic Regression model: ",rmse)
# Out:
# Accuracy of Logistic Regression model:  0.04664879356568365
# Root Mean Squared Error of Logistic Regression model:  1737.8456955846796
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#bayesian ridge regression
from sklearn.linear_model import BayesianRidge

br_model=BayesianRidge()
br_model.fit(x_train,y_train)
y_pred=br_model.predict(x_test)
accuracy=br_model.score(x_test,y_test)

print("Accuracy of Bayesian Ridge Regression model: ",accuracy)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error of Bayesian Ridge Regression model: ",rmse)
# Out:
# Accuracy of Bayesian Ridge Regression model:  0.7344379707026416
# Root Mean Squared Error of Bayesian Ridge Regression model:  884.5009157629423

# %%
#bayesian ridge regression
from sklearn.linear_model import BayesianRidge

br_model=BayesianRidge()
br_model.fit(x_train_original,y_train_original)
y_pred=br_model.predict(x_test_original)
accuracy=br_model.score(x_test_original,y_test_original)

print("Accuracy of Bayesian Ridge Regression model: ",accuracy)

rmse=np.sqrt(mean_squared_error(y_test_original,y_pred))
print("Root Mean Squared Error of Bayesian Ridge Regression model: ",rmse)
# Out:
# Accuracy of Bayesian Ridge Regression model:  0.5832616208205564
# Root Mean Squared Error of Bayesian Ridge Regression model:  2242.383059044118

# %%
#tune model linear regression

from sklearn.model_selection import GridSearchCV

param_grid={
    'fit_intercept':[True,False],
    'copy_X':[True,False]
}

grid=GridSearchCV(lr_model2,param_grid,verbose=3)
grid.fit(x_train,y_train)

grid.best_params_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ...copy_X=True, fit_intercept=True;, score=0.712 total time=   0.1s
# [CV 2/5] END ...copy_X=True, fit_intercept=True;, score=0.768 total time=   0.1s
# [CV 3/5] END ...copy_X=True, fit_intercept=True;, score=0.740 total time=   0.0s
# [CV 4/5] END ...copy_X=True, fit_intercept=True;, score=0.726 total time=   0.0s
# [CV 5/5] END ...copy_X=True, fit_intercept=True;, score=0.791 total time=   0.0s
# [CV 1/5] END ..copy_X=True, fit_intercept=False;, score=0.706 total time=   0.0s
# [CV 2/5] END ..copy_X=True, fit_intercept=False;, score=0.766 total time=   0.0s
# [CV 3/5] END ..copy_X=True, fit_intercept=False;, score=0.739 total time=   0.0s
# [CV 4/5] END ..copy_X=True, fit_intercept=False;, score=0.715 total time=   0.0s
# [CV 5/5] END ..copy_X=True, fit_intercept=False;, score=0.786 total time=   0.0s
# [CV 1/5] END ..copy_X=False, fit_intercept=True;, score=0.712 total time=   0.1s
# ...

# %%
print("Best parameters for Linear Regression model: ",grid.best_params_)
print("Best score for Linear Regression model: ",grid.best_score_)
print("Best estimator for Linear Regression model: ",grid.best_estimator_)
# Out:
# Best parameters for Linear Regression model:  {'copy_X': True, 'fit_intercept': True}
# Best score for Linear Regression model:  0.7476405717146231
# Best estimator for Linear Regression model:  LinearRegression()

# %%
#get best model mse
y_pred=grid.best_estimator_.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error of Linear Regression model: ",rmse)
# Out:
# Root Mean Squared Error of Linear Regression model:  884.7552833192145
